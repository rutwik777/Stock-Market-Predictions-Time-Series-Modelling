# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# %%
df = pd.read_csv('Silver_HistoricalData_1669917710205.csv')

# %%
df.head()
# Out:
#          Date  Close/Last   Volume    Open    High     Low
# 0  11/30/2022      21.781  62564.0  21.415  22.410  21.355
# 1  11/29/2022      21.436  45726.0  21.130  21.635  21.060
# 2  11/28/2022      21.125  57501.0  21.640  21.815  21.045
# 3  11/25/2022      21.609  30139.0  21.785  21.880  21.355
# 4  11/23/2022      21.526  20315.0  21.260  21.780  21.095

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        1259 non-null   object
#  1   Close/Last  1259 non-null   float64
#  2   Volume      1250 non-null   float64
#  3   Open        1259 non-null   float64
#  4   High        1259 non-null   float64
#  5   Low         1259 non-null   float64
# dtypes: float64(5), object(1)
# memory usage: 59.1+ KB

# %%
df.describe()
# Out:
#         Close/Last        Volume         Open         High          Low
# count  1259.000000    1250.00000  1259.000000  1259.000000  1259.000000
# mean     19.806008   62633.14320    19.820060    20.047642    19.558702
# std       4.329010   37798.69542     4.339982     4.426561     4.227206
# min      11.772000       1.00000    11.975000    12.330000    11.640000
# 25%      16.133000   42252.75000    16.140000    16.257500    15.992500
# 50%      18.168000   60558.50000    18.160000    18.400000    17.975000
# 75%      23.998000   77649.75000    24.020000    24.305000    23.617500
# max      29.418000  347002.00000    29.235000    30.350000    28.300000

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
plt.figure(figsize=(20,8))
#plt.plot(df['Close/Last'])
plt.plot(df['Date'],df['Close/Last'])
plt.ylabel('Price in $')
plt.xlabel('Days from 01-12-2017')
plt.title('Price per day from 01-12-2017 for Silver in $')
# Out:
# Text(0.5, 1.0, 'Price per day from 01-12-2017 for Silver in $')

# %%
close_data = df['Close/Last'].values
close_data = close_data.reshape((-1,1))

split_percent = 0.80
split = int(split_percent*len(close_data))

close_train = close_data[:split]
close_test = close_data[split:]

date_train = df['Date'][:split]
date_test = df['Date'][split:]

print(len(close_train))
print(len(close_test))
# Out:
# 1007
# 252

# %%
look_back = 10

train_generator = TimeseriesGenerator(close_train, close_train, length=look_back, batch_size=20)     
test_generator = TimeseriesGenerator(close_test, close_test, length=look_back, batch_size=1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# %%
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(look_back,1)))
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mse', optimizer='adam')

# %%
model.fit(train_generator, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 50/50 [==============================] - 3s 10ms/step - loss: 238.3035
# Epoch 2/100
# 50/50 [==============================] - 0s 8ms/step - loss: 91.4412
# Epoch 3/100
# 50/50 [==============================] - 0s 8ms/step - loss: 58.8543
# Epoch 4/100
# 50/50 [==============================] - 0s 7ms/step - loss: 40.3271
# Epoch 5/100
# 50/50 [==============================] - 0s 7ms/step - loss: 30.0378
# Epoch 6/100
# 50/50 [==============================] - 0s 7ms/step - loss: 24.2071
# Epoch 7/100
# 50/50 [==============================] - 0s 8ms/step - loss: 21.2656
# Epoch 8/100
# 50/50 [==============================] - 0s 7ms/step - loss: 19.8236
# Epoch 9/100
# 50/50 [==============================] - 0s 7ms/step - loss: 18.9873
# Epoch 10/100
# 50/50 [==============================] - 0s 7ms/step - loss: 18.6869
# Epoch 11/100
# 50/50 [==============================] - 0s 8ms/step - loss: 18.5735
# Epoch 12/100
# 50/50 [==============================] - 0s 7ms/step - loss: 18.5142
# Epoch 13/100
# 50/50 [==============================] - 0s 7ms/step - loss: 18.5322
# Epoch 14/100
# 50/50 [==============================] - 0s 8ms/step - loss: 18.4630
# Epoch 15/100
# 50/50 [==============================] - 0s 8ms/step - loss: 18.4300
# Epoch 16/100
# 50/50 [==============================] - 0s 8ms/step - loss: 18.4483
# Epoch 17/100
# 50/50 [==============================] - 0s 8ms/step - loss: 18.5246
# Epoch 18/100
# 50/50 [==============================] - 0s 7ms/step - loss: 18.5000
# Epoch 19/100
# 50/50 [==============================] - 0s 8ms/step - loss: 18.4834
# Epoch 20/100
# 50/50 [==============================] - 0s 8ms/step - loss: 18.4761
# Epoch 21/100
# 50/50 [==============================] - 0s 8ms/step - loss: 18.4697
# Epoch 22/100
# 50/50 [==============================] - 0s 8ms/step - loss: 18.4856
# Epoch 23/100
# 50/50 [==============================] - 0s 8ms/step - loss: 18.4855
# Epoch 24/100
# 50/50 [==============================] - 0s 8ms/step - loss: 18.5451
# Epoch 25/100
# 50/50 [==============================] - 0s 8ms/step - loss: 18.5110
# Epoch 26/100
# 50/50 [==============================] - 0s 8ms/step - loss: 18.4639
# Epoch 27/100
# 50/50 [==============================] - 0s 8ms/step - loss: 18.5004
# Epoch 28/100
# 50/50 [==============================] - 0s 8ms/step - loss: 18.4225
# Epoch 29/100
# 50/50 [==============================] - 0s 8ms/step - loss: 18.5635
# Epoch 30/100
# 50/50 [==============================] - 0s 7ms/step - loss: 18.5133
# Epoch 31/100
# 50/50 [==============================] - 0s 8ms/step - loss: 18.5063
# Epoch 32/100
# 50/50 [==============================] - 0s 8ms/step - loss: 18.5200
# Epoch 33/100
# 50/50 [==============================] - 0s 8ms/step - loss: 18.4500
# Epoch 34/100
# 50/50 [==============================] - 0s 8ms/step - loss: 17.3147
# Epoch 35/100
# 50/50 [==============================] - 0s 8ms/step - loss: 10.8342
# Epoch 36/100
# 50/50 [==============================] - 0s 8ms/step - loss: 6.6146
# Epoch 37/100
# 50/50 [==============================] - 0s 8ms/step - loss: 4.4025
# Epoch 38/100
# 50/50 [==============================] - 0s 7ms/step - loss: 3.4649
# Epoch 39/100
# 50/50 [==============================] - 0s 7ms/step - loss: 2.8092
# Epoch 40/100
# 50/50 [==============================] - 0s 7ms/step - loss: 2.2627
# Epoch 41/100
# 50/50 [==============================] - 0s 8ms/step - loss: 1.8785
# Epoch 42/100
# 50/50 [==============================] - 0s 8ms/step - loss: 1.5944
# Epoch 43/100
# 50/50 [==============================] - 0s 8ms/step - loss: 1.3705
# Epoch 44/100
# 50/50 [==============================] - 0s 8ms/step - loss: 1.2263
# Epoch 45/100
# 50/50 [==============================] - 0s 8ms/step - loss: 1.0588
# Epoch 46/100
# 50/50 [==============================] - 0s 8ms/step - loss: 1.0691
# Epoch 47/100
# 50/50 [==============================] - 0s 7ms/step - loss: 0.9010
# Epoch 48/100
# 50/50 [==============================] - 0s 8ms/step - loss: 1.0429
# Epoch 49/100
# 50/50 [==============================] - 0s 8ms/step - loss: 0.9397
# Epoch 50/100
# 50/50 [==============================] - 0s 8ms/step - loss: 0.7525
# Epoch 51/100
# 50/50 [==============================] - 0s 7ms/step - loss: 0.7001
# Epoch 52/100
# 50/50 [==============================] - 0s 8ms/step - loss: 0.5903
# Epoch 53/100
# 50/50 [==============================] - 0s 7ms/step - loss: 0.5507
# Epoch 54/100
# 50/50 [==============================] - 0s 7ms/step - loss: 0.5689
# Epoch 55/100
# 50/50 [==============================] - 0s 8ms/step - loss: 0.6795
# Epoch 56/100
# 50/50 [==============================] - 0s 8ms/step - loss: 0.6100
# Epoch 57/100
# 50/50 [==============================] - 0s 8ms/step - loss: 0.5352
# Epoch 58/100
# 50/50 [==============================] - 0s 7ms/step - loss: 0.4970
# Epoch 59/100
# 50/50 [==============================] - 0s 7ms/step - loss: 0.4272
# Epoch 60/100
# 50/50 [==============================] - 0s 7ms/step - loss: 0.4129
# Epoch 61/100
# 50/50 [==============================] - 0s 7ms/step - loss: 0.4259
# Epoch 62/100
# 50/50 [==============================] - 0s 8ms/step - loss: 0.4076
# Epoch 63/100
# 50/50 [==============================] - 0s 8ms/step - loss: 0.4037
# Epoch 64/100
# 50/50 [==============================] - 0s 8ms/step - loss: 0.4478
# Epoch 65/100
# 50/50 [==============================] - 0s 9ms/step - loss: 0.4314
# Epoch 66/100
# 50/50 [==============================] - 0s 8ms/step - loss: 0.3897
# Epoch 67/100
# 50/50 [==============================] - 1s 10ms/step - loss: 0.3478
# Epoch 68/100
# 50/50 [==============================] - 0s 9ms/step - loss: 0.3295
# Epoch 69/100
# 50/50 [==============================] - 0s 8ms/step - loss: 0.3282
# Epoch 70/100
# 50/50 [==============================] - 0s 8ms/step - loss: 0.4088
# Epoch 71/100
# 50/50 [==============================] - 0s 8ms/step - loss: 0.3375
# Epoch 72/100
# 50/50 [==============================] - 0s 9ms/step - loss: 0.3592
# Epoch 73/100
# 50/50 [==============================] - 0s 10ms/step - loss: 0.3256
# Epoch 74/100
# 50/50 [==============================] - 0s 8ms/step - loss: 0.3227
# Epoch 75/100
# 50/50 [==============================] - 0s 8ms/step - loss: 0.3092
# Epoch 76/100
# 50/50 [==============================] - 0s 8ms/step - loss: 0.3381
# Epoch 77/100
# 50/50 [==============================] - 0s 7ms/step - loss: 0.3025
# Epoch 78/100
# 50/50 [==============================] - 0s 7ms/step - loss: 0.2852
# Epoch 79/100
# 50/50 [==============================] - 0s 8ms/step - loss: 0.3084
# Epoch 80/100
# 50/50 [==============================] - 0s 8ms/step - loss: 0.2846
# Epoch 81/100
# 50/50 [==============================] - 0s 8ms/step - loss: 0.2774
# Epoch 82/100
# 50/50 [==============================] - 0s 8ms/step - loss: 0.2725
# Epoch 83/100
# 50/50 [==============================] - 0s 7ms/step - loss: 0.5124
# Epoch 84/100
# 50/50 [==============================] - 0s 7ms/step - loss: 0.3074
# Epoch 85/100
# 50/50 [==============================] - 0s 7ms/step - loss: 0.2951
# Epoch 86/100
# 50/50 [==============================] - 0s 7ms/step - loss: 0.2695
# Epoch 87/100
# 50/50 [==============================] - 0s 7ms/step - loss: 0.2888
# Epoch 88/100
# 50/50 [==============================] - 0s 8ms/step - loss: 0.3107
# Epoch 89/100
# 50/50 [==============================] - 0s 7ms/step - loss: 0.3130
# Epoch 90/100
# 50/50 [==============================] - 0s 8ms/step - loss: 0.2496
# Epoch 91/100
# 50/50 [==============================] - 0s 7ms/step - loss: 0.2420
# Epoch 92/100
# 50/50 [==============================] - 0s 8ms/step - loss: 0.2534
# Epoch 93/100
# 50/50 [==============================] - 0s 8ms/step - loss: 0.2706
# Epoch 94/100
# 50/50 [==============================] - 0s 8ms/step - loss: 0.2974
# Epoch 95/100
# 50/50 [==============================] - 0s 8ms/step - loss: 0.2635
# Epoch 96/100
# 50/50 [==============================] - 0s 8ms/step - loss: 0.2439
# Epoch 97/100
# 50/50 [==============================] - 0s 8ms/step - loss: 0.2881
# Epoch 98/100
# 50/50 [==============================] - 0s 8ms/step - loss: 0.2484
# Epoch 99/100
# 50/50 [==============================] - 0s 8ms/step - loss: 0.2427
# Epoch 100/100
# 50/50 [==============================] - 0s 8ms/step - loss: 0.2400

# %%
prediction = model.predict_generator(test_generator)

close_train = close_train.reshape((-1))
close_test = close_test.reshape((-1))
prediction = prediction.reshape((-1))

trace1 = go.Scatter(
    x = date_train,
    y = close_train,
    mode = 'lines',
    name = 'Data'
)
trace2 = go.Scatter(
    x = date_test,
    y = prediction,
    mode = 'lines',
    name = 'Prediction'
)
trace3 = go.Scatter(
    x = date_test,
    y = close_test,
    mode='lines',
    name = 'Ground Truth'
)
layout = go.Layout(
    title = " Price per day from 01-12-2017 for Silver in $ ",
    xaxis = {'title' : "Date"},
    yaxis = {'title' : "Close"}
)
fig = go.Figure(data=[trace1, trace2, trace3], layout=layout)
fig.show()
# Out:
# C:\Users\rutwi\anaconda3\lib\site-packages\keras\engine\training.py:2035: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-22bd06bed963> in <module>
#       5 prediction = prediction.reshape((-1))
#       6
# ----> 7 trace1 = go.Scatter(
#       8     x = date_train,
#       9     y = close_train,
#
# NameError: name 'go' is not defined
